kB/s eta 0:00:04
#    -------------------------------- ------- 9.2/11.3 MB 666.4 kB/s eta 0:00:04
#    -------------------------------- ------- 9.2/11.3 MB 666.4 kB/s eta 0:00:04
#    -------------------------------- ------- 9.2/11.3 MB 666.4 kB/s eta 0:00:04
#    -------------------------------- ------- 9.2/11.3 MB 666.4 kB/s eta 0:00:04
#    --------------------------------- ------ 9.4/11.3 MB 647.4 kB/s eta 0:00:03
#    --------------------------------- ------ 9.4/11.3 MB 647.4 kB/s eta 0:00:03
#    ---------------------------------- ----- 9.7/11.3 MB 644.6 kB/s eta 0:00:03
#    ---------------------------------- ----- 9.7/11.3 MB 644.6 kB/s eta 0:00:03
#    ---------------------------------- ----- 9.7/11.3 MB 644.6 kB/s eta 0:00:03
#    ---------------------------------- ----- 9.7/11.3 MB 644.6 kB/s eta 0:00:03
#    ----------------------------------- ---- 10.0/11.3 MB 629.6 kB/s eta 0:00:03
#    ----------------------------------- ---- 10.0/11.3 MB 629.6 kB/s eta 0:00:03
#    ----------------------------------- ---- 10.0/11.3 MB 629.6 kB/s eta 0:00:03
#    ----------------------------------- ---- 10.0/11.3 MB 629.6 kB/s eta 0:00:03
#    ------------------------------------ --- 10.2/11.3 MB 608.3 kB/s eta 0:00:02
#    ------------------------------------ --- 10.2/11.3 MB 608.3 kB/s eta 0:00:02
#    ------------------------------------ --- 10.2/11.3 MB 608.3 kB/s eta 0:00:02
#    ------------------------------------ --- 10.5/11.3 MB 597.0 kB/s eta 0:00:02
#    ------------------------------------ --- 10.5/11.3 MB 597.0 kB/s eta 0:00:02
#    ------------------------------------ --- 10.5/11.3 MB 597.0 kB/s eta 0:00:02
#    ------------------------------------ --- 10.5/11.3 MB 597.0 kB/s eta 0:00:02
#    ------------------------------------- -- 10.7/11.3 MB 583.1 kB/s eta 0:00:02
#    ------------------------------------- -- 10.7/11.3 MB 583.1 kB/s eta 0:00:02
#    ------------------------------------- -- 10.7/11.3 MB 583.1 kB/s eta 0:00:02
#    ------------------------------------- -- 10.7/11.3 MB 583.1 kB/s eta 0:00:02
#    ------------------------------------- -- 10.7/11.3 MB 583.1 kB/s eta 0:00:02
#    -------------------------------------- - 11.0/11.3 MB 567.1 kB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.3 MB 567.1 kB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.3 MB 567.1 kB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 561.5 kB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 557.2 kB/s eta 0:00:00
# Using cached imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Using cached scipy-1.15.3-cp310-cp310-win_amd64.whl (41.3 MB)
# Using cached sklearn_compat-0.1.3-py3-none-any.whl (18 kB)
# Using cached scikit_learn-1.6.1-cp310-cp310-win_amd64.whl (11.1 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, threadpoolctl, numpy, joblib, scipy, pandas, scikit-learn, sklearn-compat, imbalanced-learn
#
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#    ----------------------------------------  0/10 [pytz]
#    ---- -----------------------------------  1/10 [tzdata]
#    ---- -----------------------------------  1/10 [tzdata]
#    ---- -----------------------------------  1/10 [tzdata]
#    ---- -----------------------------------  1/10 [tzdata]
#    ---- -----------------------------------  1/10 [tzdata]
#    ---- -----------------------------------  1/10 [tzdata]
#    ---- -----------------------------------  1/10 [tzdata]
#    ---- -----------------------------------  1/10 [tzdata]
#    -------- -------------------------------  2/10 [threadpoolctl]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ------------ ---------------------------  3/10 [numpy]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    -------------------- -------------------  5/10 [scipy]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ------------------------ ---------------  6/10 [pandas]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    ---------------------------- -----------  7/10 [scikit-learn]
#    -------------------------------- -------  8/10 [sklearn-compat]
#    -------------------------------- -------  8/10 [sklearn-compat]
#    -------------------------------- -------  8/10 [sklearn-compat]
#    ------------------------------------ ---  9/10 [imbalanced-learn]
#    ------------------------------------ ---  9/10 [imbalanced-learn]
#    ------------------------------------ ---  9/10 [imbalanced-learn]
#    ------------------------------------ ---  9/10 [imbalanced-learn]
#    ------------------------------------ ---  9/10 [imbalanced-learn]
#    ------------------------------------ ---  9/10 [imbalanced-learn]
#    ------------------------------------ ---  9/10 [imbalanced-learn]
#    ------------------------------------ ---  9/10 [imbalanced-learn]
#    ------------------------------------ ---  9/10 [imbalanced-learn]
#    ------------------------------------ ---  9/10 [imbalanced-learn]
#    ------------------------------------ ---  9/10 [imbalanced-learn]
#    ------------------------------------ ---  9/10 [imbalanced-learn]
#    ------------------------------------ ---  9/10 [imbalanced-learn]
#    ------------------------------------ ---  9/10 [imbalanced-learn]
#    ------------------------------------ ---  9/10 [imbalanced-learn]
#    ------------------------------------ ---  9/10 [imbalanced-learn]
#    ------------------------------------ ---  9/10 [imbalanced-learn]
#    ------------------------------------ ---  9/10 [imbalanced-learn]
#    ------------------------------------ ---  9/10 [imbalanced-learn]
#    ---------------------------------------- 10/10 [imbalanced-learn]
#
# Successfully installed imbalanced-learn-0.13.0 joblib-1.5.1 numpy-2.2.6 pandas-2.3.1 pytz-2025.2 scikit-learn-1.6.1 scipy-1.15.3 sklearn-compat-0.1.3 threadpoolctl-3.6.0 tzdata-2025.2

# %%
# Load the dataset
csv_path = r"d:\Downloads\DiseasePredictions-Web-application-with-Flask-main\DataSet\diabetes.csv"
columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
           'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

# %%
# Load dataset safely
try:
    data = pd.read_csv(csv_path)
except FileNotFoundError:
    raise FileNotFoundError(f"Could not find file at {csv_path}")

# %%
# Step 2: Split features (X) and target (y)
X = data.drop('Outcome', axis=1)
y = data['Outcome']

# %%
smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X, y)

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_res, y_res, test_size=0.2, random_state=42, stratify=y_res)

# %%
# Standardize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
import joblib
import os

# Create folder
os.makedirs('saved_models', exist_ok=True)

# Save the scaler
joblib.dump(scaler, 'saved_models/diabetes_scaler.pkl')
# Out:
# ['saved_models/diabetes_scaler.pkl']

# %%
# Grid search parameters
param_grid_rf = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'bootstrap': [True, False]
}

# %%
# Model and tuning
rf = RandomForestClassifier(random_state=42)
grid_search_rf = GridSearchCV(
    estimator=rf,
    param_grid=param_grid_rf,
    cv=StratifiedKFold(n_splits=5),
    n_jobs=-1,
    verbose=2
)
grid_search_rf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'max_depth': [10, 20, None],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [100, 200]},
#              verbose=2)

# %%
# Best model
best_rf = grid_search_rf.best_estimator_

# %%
joblib.dump(best_rf, 'saved_models/diabetes_model.sav')
# Out:
# ['saved_models/diabetes_model.sav']

# %%
import pickle

# %%
filename = 'diabetes_model.sav'
pickle.dump(best_rf, open(filename, 'wb'))
